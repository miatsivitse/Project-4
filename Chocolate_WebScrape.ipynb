# %%
# Dependencies
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.78M/6.78M [00:01<00:00, 4.79MB/s]

# %%
# Visit the site: http://flavorsofcacao.com/chocolate_database.html
url = 'http://flavorsofcacao.com/chocolate_database.html'
browser.visit(url)

# %%
# Create a Beautiful Soup object
html = browser.html
b_soup = soup(html, 'html.parser')
type(b_soup)
# Out:
# bs4.BeautifulSoup

# %%
results = b_soup.find_all('div', class_='list_text')

# %%
#View Results
print(b_soup.prettify())
# Out:
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <!-- InstanceBegin template="/Templates/Logo Button Template Final.dwt" codeOutsideHTMLIsLocked="false" -->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <!-- InstanceBeginEditable name="doctitle" -->
#   <title>
#    Flavors of Cacao - Chocolate Database
#   </title>
#   <!-- InstanceEndEditable -->
#   <style type="text/css">
#    body {
# 	background-color: #FFF;
# }
#   </style>
#   <link href="header.css" rel="stylesheet" type="text/css"/>
#   <style type="text/css">
#    a:link {
# 	color: #300;
# 	text-decoration: none;
# }
# a:visited {
# 	text-decoration: none;
# 	color: #300;
# }
# a:hover {
# 	text-decoration: none;
# 	color: #285c93
# }
# a:active {
# 	text-decoration: none;
# 	color: #300;
# }
# .styleone:link {
# 	font-weight: normal;
# 	color: #300;
# 	text-decoration: none;
# 	font-size: 14px;
# }
# .styleone:visited {
# 	font-weight: normal;
# 	color:#300;
# ...

# %%
# Extract all data
table = b_soup.find('font', border='1')
records = b_soup.find_all('tr')

# %%
# New empty list
chocolate_df= []
# Loop through data, create a list of rows
for record in records:  
    record_info = {}
    REF = record.find_all('td')[0].text
    Company_Manufacturer = record.find_all('td')[1].text
    Company_Location = record.find_all('td')[2].text
    Review_Date = record.find_all('td')[3].text
    Country_Bean_Origin = record.find_all('td')[4].text
    Bean_Bar_Name = record.find_all('td')[5].text
    Cocoa_Percent = record.find_all('td')[6].text
    Ingredients = record.find_all('td')[7].text
    Characteristics = record.find_all('td')[8].text
    Rating = record.find_all('td')[9].text
#     print fields
    
    record_info = {
    "REF": REF, 
    "Company (Manufacturer)" : Company_Manufacturer,
    "Company Location" : Company_Location,
    "Review Date": Review_Date,
    "Country of Bean Origin": Country_Bean_Origin,
    "Bean/Bar Name" : Bean_Bar_Name,
    "Cocoa Percent" : Cocoa_Percent,
    "Ingredients" : Ingredients,
    "Characteristics" : Characteristics,
    "Rating" : Rating
    }

    chocolate_df.append(record_info)
record_info
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23972\1685907972.py in <module>
#       5     record_info = {}
#       6     REF = record.find_all('td')[0].text
# ----> 7     Company_Manufacturer = record.find_all('td')[1].text
#       8     Company_Location = record.find_all('td')[2].text
#       9     Review_Date = record.find_all('td')[3].text
#
# IndexError: list index out of range

# %%
# Create DataFrame
chocolate_data_df=pd.DataFrame(chocolate_df)
chocolate_data_df
